# %% [markdown]
# ## Import the needed packages: `pandas`, `matplotlib`, `seaborn`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Read the data from the file `HR_DS`into a pandas dataFrame and display the first 5 rows.

# %%
hr_ds = pd.read_csv("HR_DS.csv")
hr_ds.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Exploring the data

# %%
n_rows, n_cols = hr_ds.shape
print(f'The dataset has {n_rows} rows and {n_cols} columns')
# Out:
# The dataset has 1470 rows and 35 columns

# %% [markdown]
# ## Number of columns and rows.

# %%
hr_ds.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Checking the variables types and additional information

# %%
hr_ds.dtypes
#26 numerical variables and 9 categorical
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
#hr_ds.info

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ### Numerical variables

# %%
#numerical variables
hr_ds.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1470.0   1024.865306   602.024335     1.0   491.25
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# JobSatisfaction           1470.0      2.728571     1.102846     1.0     2.00
# ...

# %%
hr_ds['EmployeeCount'].value_counts()
# Out:
# 1    1470
# Name: EmployeeCount, dtype: int64

# %%
hr_ds['StandardHours'].value_counts()
# Out:
# 80    1470
# Name: StandardHours, dtype: int64

# %%
#Skewness: 
hr_ds.skew()
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# ...

# %% [markdown]
# Low skewness:
#
# `Moderate skewness (between |0.5| and |1.0|):` JobInvolvement, WorkingLifebalance, TrainingTimeslastYear, PercentSalaryHike, YearsWithCurrManager,YearsInCurrentRole
#
# `High skewness (higher than |1.0|):` JobLevel, NumCompaniesWorked, TotalWorkingYears, MonthlyIncome, YearsAtCompany, PerformanceRating, YearsSinceLastPromotion

# %% [markdown]
# High Curtosis in variables: `YearsAtCompany` and `YearsSinceLastPromotion`

# %%
fig, axes = plt.subplots(1,2, figsize = (14,6))
sns.boxplot(ax = axes [0], data = hr_ds, x = 'YearsAtCompany')
sns.boxplot(ax = axes [1], data = hr_ds, x = 'YearsSinceLastPromotion')
plt.show()

# %%
fig, axes = plt.subplots(1,2, figsize = (14,6))
sns.histplot(ax = axes [0], data = hr_ds, x = 'YearsAtCompany')
sns.histplot(ax = axes [1], data = hr_ds, x = 'YearsSinceLastPromotion')
plt.show()

# %%
hr_cols_to_plot = ['YearsAtCompany', 'YearsSinceLastPromotion', 'Age', 'JobRole']
sns.pairplot(hr_ds[hr_cols_to_plot],diag_kind = 'kde', kind = 'reg', plot_kws = {'line_kws':{'color': 'red'}})
#fig, axes = plt.subplots(1,2, figsize = (14,6))
#sns.histplot(ax = axes [0], data = hr_ds, x = 'YearsAtCompany')
#sns.histplot(ax = axes [1], data = hr_ds, x = 'YearsSinceLastPromotion')
plt.show()

# %% [markdown]
# ### Categorical variables

# %%
#Categorical variables
hr_ds.describe(include='O')
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
hr_ds['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %% [markdown]
# Concerning to 'Business Travel' we have three types of business: "Rarely", "Frequentely" and Non-Travel.

# %%
hr_ds['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
hr_ds['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
hr_ds['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
hr_ds['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
hr_ds['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
hr_ds['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %% [markdown]
# ## Checking for missing values

# %%
hr_ds.isna().sum()
#No missing values
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#Drop variables with unary values

#Categorical variables
#hr_ds.drop('Over18', axis = 1, inplace = True)

#Numerical variables
#hr_ds.drop('StandardHours', axis = 1, inplace = True)
#hr_ds.drop('EmployeeCount', axis = 1, inplace = True)

# %%
n_rows, n_cols = hr_ds.shape
print(f'The dataset has {n_rows} rows and {n_cols} columns')
# Out:
# The dataset has 1470 rows and 35 columns

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Numerical Variables

# %%
#Correlations
hr_corr = hr_ds.corr(method = 'spearman')
hr_corr
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.007290         -0.019291   0.204937
# DailyRate                 0.007290   1.000000         -0.002754  -0.013607
# DistanceFromHome         -0.019291  -0.002754          1.000000   0.015708
# Education                 0.204937  -0.013607          0.015708   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.001770  -0.051800          0.038906   0.042815
# EnvironmentSatisfaction   0.009820   0.018961         -0.010401  -0.027625
# HourlyRate                0.028858   0.023511          0.020446   0.014432
# JobInvolvement            0.034456   0.042469          0.034430   0.037231
# JobLevel                  0.489618   0.003816          0.022148   0.107419
# JobSatisfaction          -0.005185   0.027829         -0.013078  -0.005175
# ...

# %%
#Heat map 1
hr_corr = hr_ds.corr(method = 'spearman')
figure = plt.figure(figsize = (16,10))
sns.heatmap(hr_corr, annot = True, fmt = '.1g')
#sns.heatmap(hr_corr)
# Out:
# <AxesSubplot:>

# %%
#Heat Map 2: coloured, without annotations
hr_corr = hr_ds.corr(method = 'spearman')
figure = plt.figure(figsize = (16,16))
sns.heatmap(hr_corr,  cmap = 'coolwarm', annot = True, fmt = '.1g', vmin = -1, vmax = 1)
plt.show()

# %%
#Heat Map 4: coloured: Red to Blue , with annotations and with min and max values
hr_corr = hr_ds.corr(method = 'spearman')
figure = plt.figure(figsize = (16,16))
sns.heatmap(hr_corr,  cmap = 'RdBu',  annot = True, square = True, fmt = '.1g')
plt.show()

# %%
hr_corr_p = hr_ds.corr(method = 'pearson')
figure = plt.figure(figsize = (16,16))
sns.heatmap(hr_corr_p,  cmap = 'RdBu',  annot = True, square = True, fmt = '.1g')
plt.show()

# %%
#sns.pairplot(hr_ds)

# %%
hr_cols_to_plot = ['YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'JobRole']
hr_cols_to_plot
# Out:
# ['YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'JobRole']

# %%
sns.pairplot(hr_ds[hr_cols_to_plot],diag_kind = 'kde', kind = 'reg', plot_kws = {'line_kws':{'color': 'red'}})
plt.show()

# %%
sns.pairplot(hr_ds[hr_cols_to_plot],hue = 'JobRole')
plt.show()

# %% [markdown]
# ## Data Reduction

# %% [markdown]
# 1. Multicollinearity - Check correlation
#
# Drop variables with high correlation?
# 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager'

# %% [markdown]
# 2. Unary Variables

# %%
#Drop variables with unary values

#Categorical variables
#hr_ds.drop('Over18', axis = 1, inplace = True)

#Numerical variables
#hr_ds.drop('StandardHours', axis = 1, inplace = True)
#hr_ds.drop('EmployeeCount', axis = 1, inplace = True)
